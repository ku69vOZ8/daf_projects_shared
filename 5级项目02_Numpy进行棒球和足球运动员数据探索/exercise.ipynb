# %%
'''
Your First NumPy Array
您的第一个NumPy阵列

100xp
In this chapter, we're going to dive into the world of baseball. Along the way, you'll get comfortable with the basics of numpy, a powerful package to do data science.
在这一章中，我们将深入了解棒球的世界。一路走来，你会得到并熟悉numpy的基础知识，这是一个功能强大的包去做数据科学。

A list baseball has already been defined in the Python script, representing the height of some baseball players in centimeters. Can you add some code here and there to create a numpy array from it?
在Python脚本中，已经定义了一个列表baseball，用厘米数表示一些棒球运动员高度。你可以在这里和那里添加一些代码来创建一个numpy并从中得到阵列吗？

Instructions
-Import the numpy package as np, so that you can refer to numpy with np.
-Use np.array() to create a numpy array from baseball. Name this array np_baseball.
-Print out the type of np_baseball to check that you got it right.
说明
-导入numpy包为np，这样你就可以用np来引用numpy。
-使用 np.array() 从 baseball 创建一个 numpy 数组。将这个数组命名为 np_baseball。
-打印出 np_baseball 的类型，以检查你是否正确。
'''

# Create list baseball
baseball = [180, 215, 210, 210, 188, 176, 209, 200]
# 创建列表棒球
#棒球 = [180, 215, 210, 210, 188, 176, 209, 200]

# Import the numpy package as np
# 将 numpy 包导入为 np。

# Create a numpy array from baseball: np_baseball
# 从baseball创建一个numpy数组：np_baseball。

# Print out type of np_baseball
# 打印出np_baseball的类型。
# Out:
# <class 'numpy.ndarray'>

# %%
'''
Baseball players' height
棒球运动员的身高
100xp
You are a huge baseball fan. You decide to call the MLB (Major League Baseball) and ask around for
some more statistics on the height of the main players. They pass along data on more than a
thousand players, which is stored as a regular Python list: height. The height is expressed in
inches. Can you make a numpy array out of it and convert the units to meters?
你是一个超级棒球迷。你决定打电话给MLB（美国职业棒球大联盟）并向周围的人打听更多主力球员的身高的统计数据。他们传来的数据不止是千名球员，这些数据被存储为一个常规的Python列表：高度用英寸。你能不能把它做成一个numpy数组，然后把单位转换成米？

height is already available and the numpy package is loaded, so you can start straight away
(Source: stat.ucla.edu).
高度已经有了，而且numpy包也加载了，所以你可以直接开始使用。
（来源：stat.ucla.edu）。

Instructions
说明
-Create a numpy array from height. Name this new array np_height_in.
-从高度创建一个numpy数组。命名这个新数组为np_height_in。

-Print np_height_in.
-打印 np_height_in。

-Multiply np_height_in with 0.0254 to convert all height measurements from inches to meters.
Store the new values in a new array, np_height_m.
-用0.0254乘以np_height_in，将所有的高度测量值从英寸转换为米。
将新的数值存储在一个新的数组中，np_height_m。

-Print out np_height_m and check if the output makes sense.
-打印出np_height_m并检查输出是否合理。
'''

import pandas as pd
baseball = pd.read_csv('_datasets/baseball.csv')
height = list(baseball['Height'])

# height is available as a regular list
# 高度可作为常规列表

# Import numpy
import numpy as np
#导入numpy
#导入 numpy 作为 np

# Create a numpy array from height_i: np_height_in
# 从height_i创建一个numpy数组：np_height_in。

# Print out np_height_in
# 打印出 np_height_in。

# Convert np_height_in to m: np_height_m
# 将np_height_in转换为m：np_height_m。

# Print np_height_m
# 打印 np_height_m
# Out:
# [74 74 72 ... 75 75 73]
# [1.8796 1.8796 1.8288 ... 1.905  1.905  1.8542]

# %%
'''
Baseball player's BMI
棒球运动员的体重指数

100xp

The MLB also offers to let you analyze their weight data. Again, both are available as regular
Python lists: height and weight. height is in inches and weight is in pounds.
MLB还提供让你分析他们的体重数据。同样，两者都可以作为常规的Python列出了：身高和体重，身高的单位是英寸，体重的单位是磅。

It's now possible to calculate the BMI of each baseball player. Python code to convert height to
a numpy array with the correct units is already available in the workspace. Follow the instructions
step by step and finish the game!
现在可以计算出每个棒球运动员的BMI。将身高转换为体重的Python代码。工作区中已经有了正确单位的numpy数组。请按照以下说明进行操作逐步完成游戏!

Instructions
-Create a numpy array from the weight list with the correct units. Multiply by 0.453592 to go from
pounds to kilograms. Store the resulting numpy array as np_weight_kg.
-Use np_height_m and np_weight_kg to calculate the BMI of each player. Use the following equation:
BMI=weight(kg) / height(m) ** 2
Save the resulting numpy array as bmi.
-Print out bmi.
游戏说明
-用正确的单位从重量列表中创建一个numpy数组。乘以0.453592，得到的是磅到公斤，将得到的numpy数组存储为np_weight_kg。
-使用 np_height_m 和 np_weight_kg 来计算每个选手的 BMI。使用下面的公式。
BMI=weight(kg) / height(m) ** 2。
将生成的numpy数组保存为bmi。
-打印出bmi。
'''

import pandas as pd
baseball = pd.read_csv('_datasets/baseball.csv')
baseball.head()
height = list(baseball['Height'])
weight = list(baseball['Weight'])

# height and weight are available as regular lists
# 身高和体重可作为常规清单提供

# Import numpy
#导入numpy

import numpy as np

# Create array from height_in with metric units: np_height_m
#用公制单位height_in创建数组：np_height_m。

np_height_m = np.array(height) * 0.0254

# Calculate the BMI: bmi
# 计算BMI：bmi

# Print out bmi
# 打印出bmi
# Out:
# [23.11037639 27.60406069 28.48080465 ... 25.62295933 23.74810865
#  25.72686361]

# %%
'''

Lightweight baseball players
轻量级棒球运动员

To subset both regular Python lists and numpy arrays, you can use square brackets:
要对常规的 Python 列表和 numpy 数组进行子集，可以使用方括号。

100 XP

x = [4 , 9 , 6, 3, 1]
x[1]
x = [4 , 9 , 6, 3, 1]
x[1]

import numpy as np
y = np.array(x)
y[1]
导入 numpy 作为 np
y = np.array(x)
y[1]

For numpy specifically, you can also use boolean numpy arrays:
具体到numpy，你也可以使用布尔numpy数组。

high = y > 5
y[high]
high = y > 5
y[高]

The code that calculates the BMI of all baseball players is already included. Follow the instructions and reveal interesting things from the data!
代码已经包含计算所有棒球运动员BMI。按照说明，从数据中揭示出有趣的事情。

Instructions
-Create a boolean numpy array: the element of the array should be True if the corresponding baseball player's BMI is below 21. You can use the < operator for this. Name the array light.
-Print the array light.
-Print out a numpy array with the BMIs of all baseball players whose BMI is below 21. Use light inside square brackets to do a selection on the bmi array.
使用说明
-创建一个boolean numpy数组：如果对应的棒球运动员的BMI指数低于21，数组中的元素应该是True。你可以使用<操作符来实现。命名数组light。
-打印数组light。
-打印出一个numpy数组，其中包含所有BMI低于21的棒球运动员的BMI。使用方括号内的light对bmi数组进行选择。
'''

# height and weight are available as regular lists
# 身高和体重可作为常规清单提供

# Import numpy
#导入numpy

import numpy as np

# Calculate the BMI: bmi
# 计算BMI：bmi

np_height_m = np.array(height) * 0.0254
np_weight_kg = np.array(weight) * 0.453592
bmi = np_weight_kg / np_height_m ** 2

# Create the light array
# 创建灯光阵列

# Print out light
# 打印出光

# Print out BMIs of all baseball players whose BMI is below 21
# 打印出所有体重指数低于21的棒球运动员的体重指数。
# Out:
# [False False False ... False False False]
# [20.54255679 20.54255679 20.69282047 20.69282047 20.34343189 20.34343189
#  20.69282047 20.15883472 19.4984471  20.69282047 20.9205219 ]

# %%
'''
NumPy Side Effects
NumPy副作用
50xp
As Filip explained before, numpy is great for doing vector arithmetic. If you compare its
functionality with regular Python lists, however, some things have changed.
正如 Filip 之前所解释的那样，numpy 对于做向量运算是很好的。然而，如果你把它的功能与常规的Python列表相比，有些东西已经发生了变化。

First of all, numpy arrays cannot contain elements with different types. If you try to build
such a list, some of the elements' types are changed to end up with a homogeneous list. This
is known as type coercion.
首先，numpy 数组不能包含不同类型的元素。如果你尝试构建 这样的一个列表，一些元素的类型被改变，最终得到一个同质的列表。这个被称为类型胁迫。

Second, the typical arithmetic operators, such as +, -, * and / have a different meaning for
regular Python lists and numpy arrays.
其次，典型的算术运算符，如+、-、*和/等，其意义也不同 常规的Python列表和numpy数组

Have a look at this line of code:
请看这行代码。

np.array([True, 1, 2]) + np.array([3, 4, False])
Can you tell which code chunk builds the exact same Python object? The numpy package is already
imported as np, so you can start experimenting in the IPython Shell straight away!
np.array([True, 1, 2]) + np.array([3, 4, False])
你能知道哪个代码块构建的Python对象是完全一样的吗？numpy包已经是导入为np，所以你可以直接在IPython Shell中开始实验了。

Possible Answers
-np.array([True, 1, 2, 3, 4, False])
-np.array([4, 3, 0]) + np.array([0, 2, 2])
-np.array([1, 1, 2]) + np.array([3, 4, -1])
-np.array([0, 1, 2, 3, 4, 5])
可能的答案
-np.array([True, 1, 2, 3, 4, False])
-np.array([4，3，0]) + np.array([0，2，2])
-np.array([1，1，2]) + np.array([3，4，-1])
-np.array([0, 1, 2, 3, 4, 5])
'''

# Write your answer here
#在这里写下你的答案
# Out:
# array([4, 5, 2])

# %%
'''
Subsetting NumPy Arrays
子集NumPy数组
100xp
You've seen it with your own eyes: Python lists and numpy arrays sometimes behave differently.
你已经亲眼看到了。Python列表和numpy数组有时会有不同的表现。

Luckily, there are still certainties in this world. For example, subsetting (using the square
bracket notation on lists or arrays) works exactly the same. To see this for yourself, try the
following lines of code in the IPython Shell:
幸运的是，这个世界上还是有一些确定性的东西。例如，子集 (使用平方的 在列表或数组上使用括号符号）的工作原理完全相同。要想亲眼看到这一点，请尝试使用 以下是IPython Shell中的代码行。

x = ["a", "b", "c"]
x[1]
x = ["a", "b", "c"]
x[1]

np_x = np.array(x)
np_x[1]
The script on the right already contains code that imports numpy as np, and stores both the
height and weight of the MLB players as numpy arrays.
np_x = np.array(x)
np_x[1]
右边的脚本已经包含了将 numpy 导入为 np 的代码，并将 numpy 中的 MLB球员的身高和体重作为numpy数组。

Instructions
-Subset np_weight: print out the element at index 50.
-Print out a sub-array of np_height: It contains the elements at index 100 up to and including index 110
说明
-np_weight子集：打印出索引50处的元素。
-打印np_height的子数组：它包含索引100到索引110的元素。
'''

# height and weight are available as a regular lists
# 身高和体重可作为常规清单提供。

# Import numpy
#导入numpy
import numpy as np

# Store weight and height lists as numpy arrays
# 以numpy数组的形式存储重量和高度列表。

np_weight = np.array(weight)
np_height = np.array(height)

# Print out the weight at index 50
# 打印出指数为50的重量


# Print out sub-array of np_height_in: index 100 up to and including index 110
# 打印出np_height_in的子数组：索引100到索引110。
# Out:
# 200
# [73 74 72 73 69 72 73 75 75 73 72]

# %%
'''
Before working on the actual MLB data, let's try to create a 2D numpy array from a small
 list of lists.
在研究实际的MLB数据之前，我们先尝试从一个小的数据中创建一个二维numpy数组列表。

In this exercise, baseball is a list of lists. The main list contains 4 elements.
Each of these elements is a list containing the height and the weight of 4 baseball
players, in this order. baseball is already coded for you in the script.
在这个练习中，棒球是一个列表的列表。主列表包含4个元素。这些元素中的每个元素都是一个包含4个棒球的高度和重量的列表。棒球已经在脚本中为您编写了代码。

Instructions
-Use np.array() to create a 2D numpy array from baseball. Name it np_baseball.
-Print out the type of np_baseball.
-Print out the shape attribute of np_baseball. Use np_baseball.shape.

脚本说明
-使用 np.array() 从 baseball 创建一个 2D numpy 数组。将其命名为 np_baseball。
-打印出np_baseball的类型。
-打印出 np_baseball 的 shape 属性。使用 np_baseball.shape。
'''
# Create baseball, a list of lists
#创建棒球，一个列表的列表

baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

# Import numpy、
#导入numpy
import numpy as np

# Create a 2D numpy array from baseball: np_baseball
# 从baseball创建一个2D numpy数组：np_baseball。

# Print out the type of np_baseball
# 打印出np_baseball的类型。

# Print out the shape of np_baseball
# 打印出np_baseball的形状。
# Out:
# <class 'numpy.ndarray'>
# (4, 2)

# %%
'''
Baseball data in 2D form
棒球数据的2D形式

100xp
You have another look at the MLB data and realize that it makes more sense to
restructure all this information in a 2D numpy array. This array should have
1015 rows, corresponding to the 1015 baseball players you have information on, 
nd 2 columns (for height and weight).
你再看一下MLB的数据，发现这样做更有意义。
将所有这些信息重组到一个二维numpy数组中。这个数组应该有 1015行，对应你所掌握的1015名棒球运动员信息。nd 2列（用于身高和体重）。

The MLB was, again, very helpful and passed you the data in a different structure,
MLB又是非常有帮助的，把数据以不同的结构传给你。

a Python list of lists. 
一个 Python 列表。

In this list of lists, each sublist represents the height
and weight of a single baseball player. The name of this embedded list is baseball.

在这个列表中，每个子列表都代表着高度。和体重的单一棒球运动员。这个嵌入式列表的名字是baseball。

Can you store the data as a 2D array to unlock numpy's extra functionality?
你可以将数据存储为一个2D数组来释放numpy的额外功能吗？

Instructions
Use np.array() to create a 2D numpy array from baseball. Name it np_baseball.
Print out the shape attribute of np_baseball.
说明
使用 np.array() 从 baseball 创建一个 2D numpy 数组。将其命名为 np_baseball。
打印出 np_baseball 的形状属性。
'''

import pandas as pd
baseball = pd.read_csv('_datasets/baseball.csv')
baseball = baseball[["Height", "Weight"]]
baseball.head()

# baseball is available as a regular list of lists
# 棒球作为一个常规的列表，可供使用。

# Import numpy package
#导入numpy包

import numpy as np

# Create a 2D numpy array from baseball: np_baseball
# 从baseball创建一个2D numpy数组：np_baseball。

# Print out the shape of np_baseball
# 打印出np_baseball的形状。
# Out:
# (1015, 2)

# %%
'''
Subsetting 2D NumPy Arrays
子集二维NumPy数组。

100xp
If your 2D numpy array has a regular structure, i.e. each row and column has a
fixed number of values, complicated ways of subsetting become very easy.
Have a look at the code below where the elements "a" and "c" are extracted
from a list of lists.
如果你的二维numpy数组有一个规则的结构，即每一行和每一列都有固定数量的值，那么复杂的子集方法就变得非常容易。
看看下面的代码，其中的元素 "a "和 "c "是从列表中提取的。

# regular list of lists
# 常规列表
x = [["a", "b"], ["c", "d"]]
[x[0][0], x[1][0]]

# numpy
import numpy as np
np_x = np.array(x)
np_x[:,0]

For regular Python lists, this is a real pain. For 2D numpy arrays, however,
it's pretty intuitive! The indexes before the comma refer to the rows, while
those after the comma refer to the columns. The : is for slicing; in this example,
it tells Python to include all rows.
对于常规的Python列表来说，这是一个非常痛苦的事情。然而，对于二维 numpy 数组来说，这是很直观的！逗号前的索引指的是行，而逗号后的索引指的是列。逗号前的索引指的是行，而逗号后的索引指的是列。:是用来分片的，在这个例子中，它告诉 Python 包含所有的行。

The code that converts the pre-loaded baseball list to a 2D numpy array is already
in the script. The first column contains the players' height in inches and the second
column holds player weight, in pounds. Add some lines to make the correct selections.
请记住，在Python中，第一个元素在索引0处。
Remember that in Python, the first element is at index 0!
将预加载的棒球列表转换为二维 numpy 数组的代码已经是脚本中。第一列包含球员的身高，单位是英寸，第二列包含球员的身高。
栏里有选手的体重，以磅为单位。添加一些行来进行正确的选择。


Instructions
-Print out the 50th row of np_baseball.
-Make a new variable, np_weight, containing the entire second column of np_baseball.
-Select the height (first column) of the 124th baseball player in np_baseball and print it out.
说明
-打印出np_baseball的第50行。
-创建一个新的变量，np_weight，包含整个np_baseball的第二列。
-在np_baseball中选择第124个棒球运动员的高度(第一列)并打印出来。
'''

# baseball is available as a regular list of lists
# 棒球是可以作为一个常规的列表的列表
# Import numpy package
#导入numpy包
import numpy as np

# Create np_baseball (2 cols)
# 创建 np_baseball (2 cols)
np_baseball = np.array(baseball)

# Print out the 50th row of np_baseball
# 打印出np_baseball的第50行。

# Select the entire second column of np_baseball: np_weight_lb
# 选择np_baseball的整个第二列：np_weight_lb。

# Print out height of 124th player
# 打印出第124名选手的身高
# Out:
# [ 70 195]
# 75

# %%
'''
2D Arithmetic
二维算术

100xp
Remember how you calculated the Body Mass Index for all baseball players?
还记得你如何计算所有棒球运动员的身体质量指数吗？
numpy was able to perform all calculations element-wise (i.e. element by element).
numpy能够以元素的方式进行所有的计算（即一个元素一个元素的计算）。

For 2D numpy arrays this isn't any different! You can combine matrices with single
numbers, with vectors, and with other matrices.
对于二维的numpy数组来说，这并没有什么不同。你可以将矩阵与单个 数字、向量和其他矩阵。




import numpy as np
np_mat = np.array([[1, 2],
                   [3, 4],
                   [5, 6]])
np_mat * 2
np_mat + np.array([10, 10])
np_mat + np_mat

np_baseball is coded for you; it's again a 2D numpy array with 3 columns representing
height, weight and age.
np_baseball是为你编码的，它又是一个2D的numpy数组，有3列代表 身高、体重和年龄。

Instructions
说明

-You managed to get hold of the changes in weight, height and age of all baseball players.
-你设法掌握了所有棒球运动员的体重、身高和年龄的变化。

It is available as a 2D numpy array, updated. Add np_baseball and updated and print out the result.
它是以二维numpy数组的形式存在的，update。添加np_baseball和update并打印出结果。

-You want to convert the units of height and weight. As a first step, create a numpy array
with three values: 0.0254, 0.453592 and 1. Name this array conversion.
-你想转换身高和体重的单位。第一步，创建一个numpy数组。有三个值。命名这个数组的转换值。 -将np_baseball与转换值相乘，并打印出结果。

-Multiply np_baseball with conversion and print out the result.
-将np_baseball与转换数相乘，并打印出结果。

Execute the code below in the IPython shell and see if you understand:
在IPython shell中执行下面的代码，看看你是否理解。
'''

import pandas as pd
baseball = pd.read_csv('_datasets/baseball.csv')
baseball = baseball[["Height", "Weight", "Age"]]
baseball.head()
baseball.info


# baseball is available as a regular list of lists
# 棒球作为一个常规的列表，可供使用。

# updated is available as 2D numpy array
# 更新后可作为2D numpy数组使用

updated_weight = np.random.normal(0, size=1015).reshape(1015,1)
updated_height = np.random.rand(1015).reshape(1015,1)
updated_age = np.ones(1015).reshape(1015,1)
updated = np.hstack((updated_weight, updated_height, updated_age))


# Import numpy package
#导入numpy包
import numpy as np

# Create np_baseball (3 cols)
# 创建np_baseball(3列)
np_baseball = np.array(baseball)


# Print out addition of np_baseball and updated
# 打印出新增的np_baseball和更新的np_baseball。

# Create numpy array: conversion
# 创建numpy数组：转换

# Print out product of np_baseball and conversion
# 打印出np_baseball的乘积，并进行转换。
# Out:
# [[ 72.34296573 180.77366934  23.99      ]
#  [ 74.90996751 215.54421314  35.69      ]
#  [ 72.12036736 210.2405232   31.78      ]
#  ...
#  [ 74.11528811 205.75616336  26.19      ]
#  [ 74.87265799 190.60270926  32.01      ]
#  [ 72.96329797 195.83951021  28.92      ]]
# [[ 1.8796  81.64656 22.99   ]
#  [ 1.8796  97.52228 34.69   ]
#  [ 1.8288  95.25432 30.78   ]
#  ...
#  [ 1.905   92.98636 25.19   ]
#  [ 1.905   86.18248 31.01   ]
#  [ 1.8542  88.45044 27.92   ]]

# %%
'''
Average versus median
平均数与中位数

100xp
You now know how to use numpy functions to get a better feeling for your data.
你现在知道如何使用numpy函数来更好地感受你的数据了。

It basically comes down to importing numpy and then calling several simple functions
on the numpy arrays:
基本上就是导入numpy，然后调用几个简单的函数。在numpy数组上。

import numpy as np
x = [1, 4, 8, 10, 12]
np.mean(x)
np.median(x)
The baseball data is available as a 2D numpy array with 3 columns (height, weight, age)
and 1015 rows. The name of this numpy array is np_baseball. After restructuring the data,
however, you notice that some height values are abnormally high. Follow the instructions
and discover which summary statistic is best suited if you're dealing with so-called outliers.

导入numpy作为np
x = [1, 4, 8, 10, 12]
np.mean(x)
np.median(x)
棒球数据是一个2D numpy数组，有3列（身高、体重、年龄）和1015行。
这个numpy数组的名字是np_baseball。经过对数据的重组，但是，您注意到一些高度值异常高。
请按照以下说明进行操作并发现在处理所谓的离群值时，哪种汇总统计最适合。

Instructions
-Create numpy array np_height that is equal to first column of np_baseball.
-Print out the mean of np_height.
-Print out the median of np_height.
使用说明
-创建numpy数组np_height，等于np_baseball的第一列。
-打印出np_height的平均值。
-打印出np_height的中位数。
'''

# np_baseball is available
# np_baseball is 可用的

# Import numpy
#导入numpy

import numpy as np

# Create np_height_in from np_baseball
# 从np_baseball创建np_height_in。

# Print out the mean of np_height_in
# 打印出np_height_in的平均值。

# Print out the median of np_height_in
# 打印出np_height_in的中位数。
# Out:
# 73.6896551724138
# 74.0

# %%
'''
Explore the baseball data
探索棒球数据

100xp
Because the mean and median are so far apart, you decide to complain to the MLB.as a 2D Numpy array np_baseball, with three columns.
因为平均数和中位数相差太远，你决定向MLB投诉。

They find the error and send the corrected data over to you. It's again available
他们发现了错误，并将修正后的数据发给你。又可以用了 作为一个 2D Numpy 数组 np_baseball，有三列。

The Python script on the right already includes code to print out informative messages
with the different summary statistics. Can you finish the job?
右边的Python脚本已经包含了打印信息的代码。与不同的汇总统计。你能完成这项工作吗？

Instructions
-The code to print out the mean height is already included. Complete the code for the
median height. Replace None with the correct code.
-Use np.std() on the first column of np_baseball to calculate stddev. Replace None with
the correct code.
-Do big players tend to be heavier? Use np.corrcoef() to store the correlation between
the first and second column of np_baseball in corr. Replace None with the correct code.
说明
-已经包含了打印平均高度的代码。完成以下代码 中位数高度。用正确的代码替换None。
-使用np.std()在np_baseball的第一列计算stddev。将 None 替换为 正确的代码。
-厉害的玩家往往更重吗？使用np.corrcoef()来存储以下数据之间的相关性 corr中的np_baseball的第一和第二列。用正确的代码替换 "无"。
'''

# np_baseball is available
# np_baseball是可用的。

import numpy as np

# Import numpy
#导入numpy

# Print mean height (first column)
# 打印平均高度(第一栏)

avg = np.mean(np_baseball[:,0])
print("Average: " + str(avg))



# Print median height. Replace 'None'
# 打印中位数高度。替换 "无"。

med = None
print("Median: " + str(med))

# Print out the standard deviation on height. Replace 'None'
# 打印出高度的标准偏差。替换 "无"。


stddev = None
print("Standard Deviation: " + str(stddev))

# Print out correlation between first and second column. Replace 'None'
# 打印出第一列和第二列之间的相关性。替换 "无"。

corr = None
print("Correlation: " + str(corr))
# Out:
# Average: 73.6896551724138
# Median: 74.0
# Standard Deviation: 2.312791881046546
# Correlation: [[1.         0.53153932]
#  [0.53153932 1.        ]]

# %%
'''
Blend it all together
融合在一起
100xp

100xp
In the last few exercises you've learned everything there is to know about heights
and weights of baseball players. Now it's time to dive into another sport: soccer.
在过去的几个练习中，你已经学会了关于棒球运动员的身高和体重的一切知识。现在是时候深入研究另一项运动了：足球。

You've contacted FIFA for some data and they handed you two lists. The lists are the
following: positions = ['GK', 'M', 'A', 'D', ...] heights = [191, 184, 185, 180, ...]
Each element in the lists corresponds to a player. The first list, positions, contains
strings representing each player's position. The possible positions are: 'GK' (goalkeeper),
'M' (midfield), 'A' (attack) and 'D' (defense). The second list, heights, contains integers
representing the height of the player in cm. The first player in the lists is a goalkeeper
and is pretty tall (191 cm).
你已经联系了国际足联索取一些数据，他们给了你两份名单。这两份名单是
以下：位置 = ['GK', 'M', 'A', 'D', ...] 高度 = [191, 184, 185, 180, ...] 。
列表中的每个元素都对应一个球员。第一个列表， positions，包含代表每个球员位置的字符串。可能的位置是：'GK'(守门员) 'GK'（守门员）。'M'（中场），'A'（进攻）和'D'（防守）。第二个列表，高度，包含整数。代表球员的身高，单位是厘米。列表中的第一位球员是门将。并且身高相当高（191厘米）。

You're fairly confident that the median height of goalkeepers is higher than that of other
players on the soccer field. Some of your friends don't believe you, so you are determined
to show them using the data you received from FIFA and your newly acquired Python skills.
你相当自信，守门员的身高中位数比其他 足球场上的球员。你的一些朋友不相信你，所以你下定决心... 用你从FIFA收到的数据和你新掌握的Python技能来显示它们。

Instructions
使用说明
-Convert heights and positions, which are regular lists, to numpy arrays. Call them np_heights
and np_positions.
-将高度和位置这些常规列表转换为numpy数组。将它们称为np_heights 和 np_positions。

-Extract all the heights of the goalkeepers. You can use a little trick here: use np_positions
== 'GK' as an index for np_heights. Assign the result to gk_heights.
-提取所有守门员的高度。你可以使用一个小技巧：使用 np_positions
== 'GK' 作为 np_heights 的索引。将结果分配给gk_heights。

-Extract all the heights of all the other players. This time use np_positions != 'GK' as an
index for np_heights. Assign the result to other_heights.
-提取所有其他玩家的身高，这次使用 np_positions != 'GK' 作为索引。这次使用 np_positions != 'GK' 作为索引。np_heights的索引。将结果分配给 other_heights。

-Print out the median height of the goalkeepers using np.median(). Replace None with the correct code.
-使用np.median()打印出守门员的身高中位数。用正确的代码替换None。

-Do the same for the other players. Print out their median height. Replace None with the correct code.
-对其他球员做同样的操作。打印出他们的身高中位数。用正确的代码替换为None。
'''

fifa = pd.read_csv('./_datasets/fifa.csv')
fifa.head()
heights = fifa['height']
positions = fifa['position']

# heights and positions are available as lists
# 高度和位置可作为列表

# Import numpy
#导入numpy

import numpy as np

# Convert positions and heights to numpy arrays: np_positions, np_heights
# 将位置和高度转换为numpy数组：np_positions, np_heights。

# Heights of the goalkeepers: gk_heights
# 守门员的高度： gk_heights。


# Heights of the other players: other_heights
# 其他玩家的高度：other_heights。


# Print out the median height of goalkeepers. Replace 'None'
# 打印出守门员的身高中位数。替换 "无"。


print("Median height of goalkeepers: " + str(None))

# Print out the median height of other players. Replace 'None'
# 打印出其他选手的身高中位数。替换 "无"。

print("Median height of other players: " + str(None))
# Out:
# Median height of goalkeepers: 188.0
# Median height of other players: 181.0
